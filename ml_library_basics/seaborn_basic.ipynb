# %% [markdown]
# Seaborn:
# * Data Visualization Library

# %% [markdown]
# Importing the libraries

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# Note: Seaborn has some built-in datasets

# %%
# total bill vs tip dataset
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# setting a theme for the plots
sns.set_theme()

# %%
# visualize the data
sns.relplot(data=tips, x='total_bill', y='tip', col='time', hue='smoker', style='smoker', size='size')

# %%
# load the iris dataset
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# Scatter plot

# %%
sns.scatterplot(data=iris, x='sepal_length', y='petal_length', hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.scatterplot(data=iris, x='sepal_length', y='petal_width', hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_width'>

# %%
# loading the titanic dataset
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# Count plot

# %%
sns.countplot(data=titanic, x='class')
# Out:
# c:\Users\rashe\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='class', ylabel='count'>

# %%
titanic.shape
# Out:
# (891, 15)

# %%
sns.countplot(x='survived', data=titanic)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %% [markdown]
# Bar chart

# %%
sns.barplot(x='sex', y='survived', data=titanic, hue='class')
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
plt.pie(titanic['survived'].value_counts(), labels=titanic['survived'].unique(), autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1bdf5e7e0d0>,
# ...
#  [Text(-0.3925749350994583, 1.0275626113924428, '0'),
#   Text(0.3925750313068116, -1.0275625746369201, '1')],
#  [Text(-0.21413178278152267, 0.5604886971231505, '61.6%'),
#   Text(0.21413183525826085, -0.5604886770746836, '38.4%')])

# %%
fig = plt.figure(figsize=(10, 6))
plt.bar(titanic['class'].value_counts().index, titanic['class'].value_counts().values)
plt.xlabel('Class') 
plt.ylabel('Count')
plt.title('Count of Passengers by Class')
plt.show()

# %% [markdown]
# Distribution plot

# %%
sns.distplot(titanic['age'])
# Out:
# C:\Users\rashe\AppData\Local\Temp\ipykernel_6500\1132062727.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['age'])
# c:\Users\rashe\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='age', ylabel='Density'>

# %% [markdown]
# Correlation:
# - Positive correlation
# - Negative Correlation

# %% [markdown]
# Heat map

# %%
diabetes = pd.read_csv('diabetes.csv')
df = pd.DataFrame(diabetes)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
correlation = df.corr()

# %%
# constructing a heatmap
plt.figure(figsize=(10, 10))
ax = sns.heatmap(
    correlation,
    cmap='Blues',
    square=True,
    cbar=True,
    linewidths=0.5,
    linecolor='white'
)
for i in range(correlation.shape[0]):  # loop over rows
    for j in range(correlation.shape[1]):  # loop over columns
        ax.text(
            j + 0.5,                  # x-coordinate (column index + offset for centering)
            i + 0.5,                  # y-coordinate (row index + offset for centering)
            f'{correlation.iloc[i, j]:.2f}',  # formatted text (2 decimal places)
            ha='center',              # horizontal alignment
            va='center',              # vertical alignment
            color='black',            # text color
            fontsize=10               # text size
        )

plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# %%
print(correlation)
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Dummy correlation data
df = pd.DataFrame(np.random.rand(5, 5), columns=list('ABCDE'))
correlation = df.corr()

# Plot
plt.figure(figsize=(8, 8))
ax = sns.heatmap(
    correlation,
    cmap='Blues',
    square=True,
    cbar=True,
    linewidths=0.5,
    linecolor='white'
)

# Manually add text annotations
for i in range(correlation.shape[0]):
    for j in range(correlation.shape[1]):
        ax.text(j + 0.5, i + 0.5, f'{correlation.iloc[i, j]:.2f}',
                ha='center', va='center', color='black', fontsize=10)

plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib

print("Seaborn version:", sns.__version__)
print("Matplotlib version:", matplotlib.__version__)
# Out:
# Seaborn version: 0.12.2
# Matplotlib version: 3.8.0
