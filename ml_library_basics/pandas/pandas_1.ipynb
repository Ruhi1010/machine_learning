# %% [markdown]
# ## Introduction of Series

# %%
import numpy as nu
import pandas as pd

# %%
a = [1, 2, 3, 4, 5]

s = pd.Series(a)

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
d = {'Ruhi': 1, 'Rashid': 2, 'Rashmi': 3, 'Rashika': 4}

s = pd.Series(d)
s
# Out:
# Ruhi       1
# Rashid     2
# Rashmi     3
# Rashika    4
# dtype: int64

# %% [markdown]
# ## Introduction of DataFrame

# %%
d = pd.DataFrame({'name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
                  'age': [25, 30, 35, 40, 45],
                  'city': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix']})

d
# Out:
#       name  age         city
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston
# 4      Eve   45      Phoenix

# %%
data_frame_1 = pd.DataFrame([s])
data_frame_1
# Out:
#    Ruhi  Rashid  Rashmi  Rashika
# 0     1       2       3        4

# %% [markdown]
# ### Load .csv file

# %%
data = pd.read_csv('diabetes.csv')

data_frame = pd.DataFrame(data)

# %% [markdown]
# ##### Show first 5 rows of the datasets

# %%
data_frame.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ##### Show last 5 rows of the dataset

# %%
data_frame.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %% [markdown]
# ##### Sample example of data

# %%
data_frame.sample()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 397            0      131             66             40        0  34.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 397                     0.196   22        1

# %% [markdown]
# ##### Analyze the data

# %%
# Basic Statistics of the dataset
data_frame.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
# Check the count of rows and columns in the dataset
data_frame.shape
# Out:
# (768, 9)

# %%
# Dataset information
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# check missing values in each column
data_frame.isnull()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# ...

# %%
# Check total missing values of the dataset for each column
data_frame.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data_frame.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
data_frame.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data_frame['Glucose'].head()
# Out:
# 0    148
# 1     85
# 2    183
# 3     89
# 4    137
# Name: Glucose, dtype: int64

# %%
# Check the count of unique values in the Outcome column
data_frame['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
# multiple columns can be selected by passing a list of column names to the DataFrame. For example, to select the 'BMI', 'BloodPressure', and 'Glucose' columns, you can use the following code:
data_frame[['BMI', 'BloodPressure', 'Glucose']].head()
# Out:
#     BMI  BloodPressure  Glucose
# 0  33.6             72      148
# 1  26.6             66       85
# 2  23.3             64      183
# 3  28.1             66       89
# 4  43.1             40      137

# %%
data_frame.Pregnancies.head()
# Out:
# 0    6
# 1    1
# 2    8
# 3    1
# 4    0
# Name: Pregnancies, dtype: int64

# %%
special_index = data_frame.set_index('Pregnancies')

# %%
special_index.head()
# Out:
#              Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Pregnancies
# 6                148             72             35        0  33.6
# 1                 85             66             29        0  26.6
# 8                183             64              0        0  23.3
# 1                 89             66             23       94  28.1
# 0                137             40             35      168  43.1
#
#              DiabetesPedigreeFunction  Age  Outcome
# Pregnancies
# 6                               0.627   50        1
# 1                               0.351   31        0
# 8                               0.672   32        1
# 1                               0.167   21        0
# 0                               2.288   33        1

# %%
special_index.loc[8].head()
# Out:
#              Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Pregnancies
# 8                183             64              0        0  23.3
# 8                125             96              0        0   0.0
# 8                 99             84              0        0  35.4
# 8                176             90             34      300  33.7
# 8                133             72              0        0  32.9
#
#              DiabetesPedigreeFunction  Age  Outcome
# Pregnancies
# 8                               0.672   32        1
# 8                               0.232   54        1
# 8                               0.388   50        0
# 8                               0.467   58        1
# 8                               0.270   39        1

# %%
df = pd.read_csv('../../Placement_Dataset.csv')

# %%
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
df_set_index = df.set_index('sl_no')

# %%
df_set_index.head()
# Out:
#       gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# sl_no
# 1          M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 2          M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 3          M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 4          M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 5          M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
#
#       workex  etest_p specialisation  mba_p      status    salary
# sl_no
# 1         No     55.0         Mkt&HR  58.80      Placed  270000.0
# 2        Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 3         No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 4         No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 5         No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
df_set_index.loc[1]
# Out:
# gender                   M
# ssc_p                 67.0
# ssc_b               Others
# hsc_p                 91.0
# hsc_b               Others
# hsc_s             Commerce
# degree_p              58.0
# degree_t          Sci&Tech
# workex                  No
# etest_p               55.0
# specialisation      Mkt&HR
# mba_p                 58.8
# status              Placed
# salary            270000.0
# Name: 1, dtype: object

# %%
# Index wise details can be accessed using the loc method. For example, to access the details of the row with index 1
df.loc[[1, 2, 3], ['gender', 'ssc_p', 'hsc_p']]
# Out:
#   gender  ssc_p  hsc_p
# 1      M  79.33  78.33
# 2      M  65.00  68.00
# 3      M  56.00  52.00

# %%
# slicing can be doing using the loc method. For example, to access the first three rows
df.loc[0:3]
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN

# %%
# slicing can be done using the iloc method. For example, to access the first three rows and the first two columns of the DataFrame, you can use the following code:
df.iloc[0:3, 0:2]
# Out:
#    sl_no gender
# 0      1      M
# 1      2      M
# 2      3      M

# %%
df_set_index.iloc[2:10, 0:2]
# df_set_index.loc[3:10]
# Out:
#       gender  ssc_p
# sl_no
# 3          M   65.0
# 4          M   56.0
# 5          M   85.8
# 6          M   55.0
# 7          F   46.0
# 8          M   82.0
# 9          M   73.0
# 10         M   58.0

# %%
df_set_index.loc[0:3][['gender', 'ssc_p', 'hsc_p']]
# Out:
#       gender  ssc_p  hsc_p
# sl_no
# 1          M  67.00  91.00
# 2          M  79.33  78.33
# 3          M  65.00  68.00

# %%
df.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
df.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
# Boolean filter
df['degree_p'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 210    False
# 211    False
# 212    False
# 213    False
# 214    False
# Name: degree_p, Length: 215, dtype: bool

# %%
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
df.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
df_set_index[(df_set_index['ssc_p'] > 50.0)].head(10)
# Out:
#       gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# sl_no
# 1          M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 2          M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 3          M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 4          M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 5          M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# 6          M  55.00   Others  49.80   Others   Science     67.25   Sci&Tech
# 8          M  82.00  Central  64.00  Central   Science     66.00   Sci&Tech
# 9          M  73.00  Central  79.00  Central  Commerce     72.00  Comm&Mgmt
# 10         M  58.00  Central  70.00  Central  Commerce     61.00  Comm&Mgmt
# 11         M  58.00  Central  61.00  Central  Commerce     60.00  Comm&Mgmt
#
#       workex  etest_p specialisation  mba_p      status    salary
# sl_no
# ...

# %%
df[((df['hsc_s'] == 'Science') | (df['hsc_s']== 'Commerce')) &  (df['hsc_p'] > 75) & (df['gender'] == 'M') & (df['workex'] == 'Yes')]
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 26      27      M  71.00   Others  79.00   Others  Commerce     66.00
# 28      29      M  76.76   Others  76.50   Others  Commerce     67.50
# 77      78      M  64.00   Others  80.00   Others   Science     65.00
# 83      84      M  84.00   Others  79.00   Others   Science     68.00
# 95      96      M  73.00  Central  78.00   Others  Commerce     65.00
# 103    104      M  73.00  Central  78.00  Central   Science     73.00
# 118    119      M  76.00  Central  80.00  Central   Science     78.00
# 129    130      M  76.70  Central  89.70   Others  Commerce     66.00
# 162    163      M  74.20  Central  87.60   Others  Commerce     77.25
# 171    172      M  80.00   Others  80.00   Others  Commerce     72.00
# 195    196      M  66.00  Central  76.00  Central  Commerce     72.00
# ...

# %%
df[df['hsc_s'].isin (['Science', 'Commerce'])]
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 5        6      M  55.00   Others  49.80   Others   Science     67.25
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
df[df['hsc_p'].between(70, 80)].head()
# Out:
#     sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 1       2      M  79.33  Central  78.33   Others   Science     77.48
# 4       5      M  85.80  Central  73.60  Central  Commerce     73.30
# 8       9      M  73.00  Central  79.00  Central  Commerce     72.00
# 9      10      M  58.00  Central  70.00  Central  Commerce     61.00
# 15     16      F  65.00  Central  75.00  Central  Commerce     69.00
#
#      degree_t workex  etest_p specialisation  mba_p      status    salary
# 1    Sci&Tech    Yes    86.50        Mkt&Fin  66.28      Placed  200000.0
# 4   Comm&Mgmt     No    96.80        Mkt&Fin  55.50      Placed  425000.0
# 8   Comm&Mgmt     No    91.34        Mkt&Fin  61.29      Placed  231000.0
# 9   Comm&Mgmt     No    54.00        Mkt&Fin  52.21  Not Placed       NaN
# 15  Comm&Mgmt    Yes    72.00        Mkt&Fin  64.66      Placed  200000.0

# %%
df[df['hsc_s'].str.contains('Science')].head()
# Out:
#     sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b    hsc_s  degree_p  \
# 1       2      M  79.33  Central  78.33   Others  Science     77.48
# 3       4      M  56.00  Central  52.00  Central  Science     52.00
# 5       6      M  55.00   Others  49.80   Others  Science     67.25
# 7       8      M  82.00  Central  64.00  Central  Science     66.00
# 12     13      F  47.00  Central  55.00   Others  Science     65.00
#
#      degree_t workex  etest_p specialisation  mba_p      status    salary
# 1    Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 3    Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 5    Sci&Tech    Yes     55.0        Mkt&Fin  51.58  Not Placed       NaN
# 7    Sci&Tech    Yes     67.0        Mkt&Fin  62.14      Placed  252000.0
# 12  Comm&Mgmt     No     62.0         Mkt&HR  65.04  Not Placed       NaN
